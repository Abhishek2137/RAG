# %% [markdown]
# DATA Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content i am using to create RAG",
     metadata={
         "source":"example.txt",
         "pages":1,
         "author":"John Doe",
         "date_created":"2024-06-10"
               }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'John Doe', 'date_created': '2024-06-10'}, page_content='this is the main text content i am using to create RAG')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print("Loaded:", type(document))
if hasattr(document, "__len__"):
    print("Items:", len(document))
# Out:
# Loaded: <class 'list'>
# Items: 1

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="*.txt",
    loader_cls=TextLoader,
    show_progress=False
)
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='')]

# %%
type (pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
